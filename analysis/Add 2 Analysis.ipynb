# %%
# %matplotlib inline

import json
import pandas as pd
import glob

# %%
list(raw_data)
# Out:
# ['testWorkerId', 'A2ATBS6XTIZE89']

# %%
data_directory = '/Users/andrew/Desktop/add_experiment/data/pilot1'

raw_data = {}
for filename in glob.glob(data_directory + '/*'):
    with open(filename) as f:
        data = json.load(f)
        worker_id = data['hit_params']['workerId']
        raw_data[worker_id] = data

# %%
raw_data['testWorkerId']
# Out:
# {'app_settings': {'allowedDemonstrationErrors': 2,
#   'correctReward': 0.01,
#   'delayLower': 400,
#   'delayUpper': 1000,
#   'incorrectPenalty': 0.01,
#   'maxAddend': 20,
#   'maxTrialTime': 6000,
#   'maxTypeTime': 300,
#   'numAdd2Split': 3,
#   'numCalibrationSets': 3,
#   'numDemonstrationTrials': 5,
#   'numWarmupTrials': 10,
#   'post_url': 'https://web.stanford.edu/~ajhnam/cgi-bin/post_endpoint.py',
#   'saveDirectory': 'add2/pilot1'},
#  'datastore': [{'key': 'start',
#    'screenName': 'inst_welcome',
#    'type': 'metadata',
#    'value': '2019-10-19T03:36:53.417Z'},
#   {'key': 'start',
#    'screenName': 'inst_compensation',
#    'type': 'metadata',
#    'value': '2019-10-19T03:36:53.888Z'},
#   {'key': 'start',
#    'screenName': 'inst_details',
#    'type': 'metadata',
#    'value': '2019-10-19T03:36:54.168Z'},
#   {'key': 'start',
#    'screenName': 'inst_demonstration',
#    'type': 'metadata',
#    'value': '2019-10-19T03:36:54.484Z'},
#   {'key': 'start',
# ...

# %%
raw_data['A2ATBS6XTIZE89']['datastore'][:-100]
# Out:
# [{'key': 'start',
#   'screenName': 'inst_welcome',
#   'type': 'metadata',
#   'value': '2019-10-18T23:12:06.840Z'},
#  {'key': 'start',
#   'screenName': 'inst_compensation',
#   'type': 'metadata',
#   'value': '2019-10-18T23:12:20.369Z'},
#  {'key': 'start',
#   'screenName': 'inst_details',
#   'type': 'metadata',
#   'value': '2019-10-18T23:12:20.782Z'},
#  {'key': 'start',
#   'screenName': 'inst_demonstration',
#   'type': 'metadata',
#   'value': '2019-10-18T23:12:28.884Z'},
#  {'key': 'start',
#   'screenName': 'demonstration_0',
#   'type': 'metadata',
#   'value': '2019-10-18T23:12:34.268Z'},
#  {'key': 'delay',
#   'screenName': 'demonstration_0',
#   'type': 'metadata',
#   'value': 441},
#  {'key': 'input1',
#   'screenName': 'demonstration_0',
#   'type': 'responseTime',
#   'value': 1310},
#  {'key': 'input2',
#   'screenName': 'demonstration_0',
#   'type': 'responseTime',
#   'value': 1468},
#  {'key': 'response',
#   'screenName': 'demonstration_0',
# ...

# %%
raw_data['A2ATBS6XTIZE89']['results']
# Out:
# {'add2': [[False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    False,
#    True,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    False,
#    False,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    True,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    True,
#    True,
#    False,
#    True,
#    True,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    True,
#    False,
#    False,
#    False,
#    True,
#    False,
#    True,
#    False,
#    True,
#    True,
#    True,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    True,
#    False,
#    False,
#    True,
# ...

# %%
raw_data['A2ATBS6XTIZE89']['start']
# Out:
# '2019-10-18T23:12:06.824Z'

# %%
raw_data['A2ATBS6XTIZE89']['end']
# Out:
# '2019-10-18T23:34:34.843Z'
